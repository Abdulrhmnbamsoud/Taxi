# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="S8fBnj7rYLBxTr1ZwfYW")
project = rf.workspace("l-workplace").project("mini-project3")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# [WARNING] we noticed you are downloading a `yolov8` datasets but you don't have `ultralytics` installed. Roboflow `.deploy` supports only models trained with `ultralytics==8.0.196`, to intall it `pip install ultralytics==8.0.196`.

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.8/41.8 kB 2.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 872.1/872.1 kB 22.8 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

model = YOLO('yolov8n.pt')


model.train(data="/content/Mini-project3-2/data.yaml", epochs=20, imgsz=640)


model.save("custom_yolov8_model.pt")
# Out:
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 92.5MB/s]
# Ultralytics YOLOv8.2.87 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
import cv2
from google.colab.patches import cv2_imshow

video_path = "/content/Untitled video - Made with Clipchamp (1).mp4"
cap = cv2.VideoCapture(video_path)
assert cap.isOpened(), "Error reading video file"

success, frame = cap.read()
if not success:
    print("Failed to capture the frame.")
    cap.release()
    exit()


line_points = [(100, 400), (1200, 400)]  


cv2.line(frame, line_points[0], line_points[1], (0, 255, 0), 2) 


cv2_imshow(frame)


cap.release()
# Out:
# <PIL.Image.Image image mode=RGB size=1280x720>

# %%
import cv2

from ultralytics import YOLO, solutions

model = YOLO("/content/custom_yolov8_model.pt")
cap = cv2.VideoCapture("/content/Untitled video - Made with Clipchamp (1).mp4")
assert cap.isOpened(), "Error reading video file"
w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH, cv2.CAP_PROP_FRAME_HEIGHT, cv2.CAP_PROP_FPS))

line_points = [(100, 400), (1200, 400)]


video_writer = cv2.VideoWriter("object_counting_output.avi", cv2.VideoWriter_fourcc(*"mp4v"), fps, (w, h))


counter = solutions.ObjectCounter(
    view_img=True,
    reg_pts=line_points,
    names=model.names,
    draw_tracks=True,
    line_thickness=2,
)


speed_obj = solutions.SpeedEstimator(
    reg_pts=line_points,
    names=model.names,
    view_img=True,
)

while cap.isOpened():
    success, im0 = cap.read()
    if not success:
        print("Video frame is empty or video processing has been successfully completed.")
        break

    tracks = model.track(im0, persist=True, show=False)

    im0 = counter.start_counting(im0, tracks)
    im0 = speed_obj.estimate_speed(im0, tracks) 
    video_writer.write(im0)

cap.release()
video_writer.release()
cv2.destroyAllWindows()
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
# Line Counter Initiated.
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
#
# 0: 384x640 1 Taxi, 10.4ms
# Speed: 1.9ms preprocess, 10.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Taxi, 8.8ms
# Speed: 2.6ms preprocess, 8.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Taxi, 8.0ms
# Speed: 2.2ms preprocess, 8.0ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Taxi, 7.8ms
# Speed: 2.6ms preprocess, 7.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Taxi, 6.9ms
# Speed: 2.2ms preprocess, 6.9ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Taxi, 8.4ms
# Speed: 2.3ms preprocess, 8.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Taxi, 10.5ms
# ...
